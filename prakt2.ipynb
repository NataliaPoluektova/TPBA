# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaPoluektova/TPBA/blob/main/prakt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практична робота №2
# **Тема:** Основи NumPy для економічного аналізу.
#
# ## Мета роботи
# 1. Навчитися працювати з масивами NumPy та застосовувати їх для розв’язання типових економічних задач
# ##Теоретичний вступ:
#
# **NumPy — це бібліотека для роботи з числовими масивами**. Вона дозволяє:
#
# ефективно зберігати та обробляти великі обсяги даних
#
# виконувати математичні операції над усіма елементами одразу
#
# моделювати економічні процеси: витрати, доходи, прибутки, індекси
#
# Для роботи з numpy Ви повинні її імпортувати:

# %%
import numpy as np

# %% [markdown]
# **Задача 1: Аналіз витрат**
#
# Виконайте та проаналізуйте приклад нижче:

# %%
expenses = np.array([1200, 1500, 1000, 1800, 1300])

print("Загальні витрати:", expenses.sum())
print("Середні витрати:", expenses.mean())
print("Максимальні витрати:", expenses.max())
print("Мінімальні витрати:", expenses.min())

# %% [markdown]
# **Завдання для самостійного виконання:**
# Створіть масив доходів за 6 місяців.
#
# Обчисліть
#
# загальний дохід,
#
# середній дохід,
#
# найвищий і найнижчий показник.

# %%
# Ваш код тут

# %% [markdown]
# **Задача 2: Умовна фільтрація**
# Умова: Є список витрат. Виведіть лише ті витрати, які вище 1400.
#
# Виконайте приклад нижче:

# %%
expenses = np.array([1200, 1500, 1000, 1800, 1300])
high_expenses = expenses[expenses > 1400]
print("Високі витрати:", high_expenses)

# %% [markdown]
# **Завдання для самостійного виконання:** Створіть масив доходів. Виведіть ті, що менші за 2500 грн.

# %%
incomes = [3000, 7000, 16000, 12000, 4500, 18000]
# Ваш код тут

# %% [markdown]
# **Задача 3: Розрахунок прибутку**
# Умова: Є список доходів та витрат за кілька місяців. Обчислити прибуток.
#
# Виконайте приклад нижче:

# %%
revenue = np.array([3000, 4000, 3500, 5000, 4200])
expenses = np.array([1200, 1500, 1000, 1800, 1300])
profit = revenue - expenses
print("Прибуток по місяцях:", profit)

# %% [markdown]
# **Завдання для самостійного виконання:** Створіть масиви собівартості та ціни продажу товарів. Обчисліть прибуток по кожному товару.

# %%
# Ваш код тут

# %% [markdown]
# **Задача 4: ROI (Return on Investment)
# Виконайте код нижче, проаналізуйте та напишіть в коментарі що означає цей показник

# %%
investment = np.array([10000, 15000, 12000])
return_ = np.array([1200, 2500, 1800])
roi = return_ / investment
print("ROI по проектах:", roi)

# %% [markdown]
# **Завдання для самостійного виконання:** Створіть масиви витрат на рекламу та доходів від продажів. Обчисліть ефективність реклами як дохід/витрати.

# %%
# Ваш код тут

# %% [markdown]
# **Задача 5: Двовимірний аналіз**
# Двовимірний аналіз. Виконайте код, проаналізуйте та напишіть в коментарі чим цей спосіб відрізняється від обробки двовимірних масивів без numpy

# %%
expenses_matrix = np.array([
    [1200, 1300, 1250],  # Відділ A
    [1500, 1600, 1550],  # Відділ B
    [1000, 1100, 1050]   # Відділ C
])

monthly_total = expenses_matrix.sum(axis=0)
department_total = expenses_matrix.sum(axis=1)

print("Витрати по місяцях:", monthly_total)
print("Витрати по відділах:", department_total)

# %% [markdown]
# **Завдання для самостійного виконання:** Створіть матрицю доходів по регіонах і кварталах. Обчисліть загальні доходи по кожному регіону та кварталу.

# %%
# Ваш код тут

# %% [markdown]
# **Індивідуальне завдання**
# Розв'яжіть задачу свого варіанту.
#
# Варіант1. Є список залишків товарів у штуках. Виведіть кількість товарів, які потребують поповнення (менше 10 одиниць).
#
# ![прак2.png](data:image/png;base64,...)
